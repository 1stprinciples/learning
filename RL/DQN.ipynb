# %%
import gym
from stable_baselines import DQN
from stable_baselines.common.evaluation import evaluate_policy
# Out:
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/suguthansekar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# I would like to implement DQN and understand the basic requirements involved in implementing this algorithm

# %%
# %%time
# Create environment
#env = gym.make('LunarLander-v2')
env = gym.make('CartPole-v1')
# Out:
# CPU times: user 6.08 ms, sys: 4.47 ms, total: 10.6 ms
# Wall time: 33.5 ms

# %%
# %%
# # Instantiate the agent
# model = DQN('MlpPolicy', env, learning_rate=1e-3, prioritized_replay=True, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# # Save the agent
# model.save("dqn_lunar")
# del model  # delete trained model to demonstrate loading

# %%
# Load the trained agent
model = DQN.load("dqn_lunar")

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)

# Enjoy trained agent
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print("This is the step ",i)
#env.render()
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# This is the step  0
# This is the step  1
# This is the step  2
# This is the step  3
# This is the step  4
# This is the step  5
# This is the step  6
# This is the step  7
# This is the step  8
# This is the step  9
# This is the step  10
# This is the step  11
# This is the step  12
# This is the step  13
# This is the step  14
# This is the step  15
# This is the step  16
# This is the step  17
# This is the step  18
# This is the step  19
# This is the step  20
# This is the step  21
# This is the step  22
# This is the step  23
# This is the step  24
# This is the step  25
# This is the step  26
# This is the step  27
# This is the step  28
# This is the step  29
# This is the step  30
# This is the step  31
# This is the step  32
# This is the step  33
# This is the step  34
# This is the step  35
# This is the step  36
# This is the step  37
# This is the step  38
# This is the step  39
# This is the step  40
# This is the step  41
# This is the step  42
# This is the step  43
# This is the step  44
# This is the step  45
# This is the step  46
# This is the step  47
# This is the step  48
# This is the step  49
# This is the step  50
# This is the step  51
# This is the step  52
# This is the step  53
# This is the step  54
# This is the step  55
# This is the step  56
# This is the step  57
# This is the step  58
# This is the step  59
# This is the step  60
# This is the step  61
# This is the step  62
# This is the step  63
# This is the step  64
# This is the step  65
# This is the step  66
# This is the step  67
# This is the step  68
# This is the step  69
# This is the step  70
# This is the step  71
# This is the step  72
# This is the step  73
# This is the step  74
# This is the step  75
# This is the step  76
# This is the step  77
# This is the step  78
# This is the step  79
# This is the step  80
# This is the step  81
# This is the step  82
# This is the step  83
# This is the step  84
# This is the step  85
# This is the step  86
# This is the step  87
# This is the step  88
# This is the step  89
# This is the step  90
# This is the step  91
# This is the step  92
# This is the step  93
# This is the step  94
# This is the step  95
# This is the step  96
# This is the step  97
# This is the step  98
# This is the step  99
# This is the step  100
# This is the step  101
# This is the step  102
# This is the step  103
# This is the step  104
# This is the step  105
# This is the step  106
# This is the step  107
# This is the step  108
# This is the step  109
# This is the step  110
# This is the step  111
# This is the step  112
# This is the step  113
# This is the step  114
# This is the step  115
# This is the step  116
# This is the step  117
# This is the step  118
# This is the step  119
# This is the step  120
# This is the step  121
# This is the step  122
# This is the step  123
# This is the step  124
# This is the step  125
# This is the step  126
# This is the step  127
# This is the step  128
# This is the step  129
# This is the step  130
# This is the step  131
# This is the step  132
# This is the step  133
# This is the step  134
# This is the step  135
# This is the step  136
# This is the step  137
# This is the step  138
# This is the step  139
# This is the step  140
# This is the step  141
# This is the step  142
# This is the step  143
# This is the step  144
# This is the step  145
# This is the step  146
# This is the step  147
# This is the step  148
# This is the step  149
# This is the step  150
# This is the step  151
# This is the step  152
# This is the step  153
# This is the step  154
# This is the step  155
# /Users/suguthansekar/anaconda3/envs/RL_learning/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# This is the step  156
# This is the step  157
# This is the step  158
# This is the step  159
# This is the step  160
# This is the step  161
# This is the step  162
# This is the step  163
# This is the step  164
# This is the step  165
# This is the step  166
# This is the step  167
# This is the step  168
# This is the step  169
# This is the step  170
# This is the step  171
# This is the step  172
# This is the step  173
# This is the step  174
# This is the step  175
# This is the step  176
# This is the step  177
# This is the step  178
# This is the step  179
# This is the step  180
# This is the step  181
# This is the step  182
# This is the step  183
# This is the step  184
# This is the step  185
# This is the step  186
# This is the step  187
# This is the step  188
# This is the step  189
# This is the step  190
# This is the step  191
# This is the step  192
# This is the step  193
# This is the step  194
# This is the step  195
# This is the step  196
# This is the step  197
# This is the step  198
# This is the step  199
# This is the step  200
# This is the step  201
# This is the step  202
# This is the step  203
# This is the step  204
# This is the step  205
# This is the step  206
# This is the step  207
# This is the step  208
# This is the step  209
# This is the step  210
# This is the step  211
# This is the step  212
# This is the step  213
# This is the step  214
# This is the step  215
# This is the step  216
# This is the step  217
# This is the step  218
# This is the step  219
# This is the step  220
# This is the step  221
# This is the step  222
# This is the step  223
# This is the step  224
# This is the step  225
# This is the step  226
# This is the step  227
# This is the step  228
# This is the step  229
# This is the step  230
# This is the step  231
# This is the step  232
# This is the step  233
# This is the step  234
# This is the step  235
# This is the step  236
# This is the step  237
# This is the step  238
# This is the step  239
# This is the step  240
# This is the step  241
# This is the step  242
# This is the step  243
# This is the step  244
# This is the step  245
# This is the step  246
# This is the step  247
# This is the step  248
# This is the step  249
# This is the step  250
# This is the step  251
# This is the step  252
# This is the step  253
# This is the step  254
# This is the step  255
# This is the step  256
# This is the step  257
# This is the step  258
# This is the step  259
# This is the step  260
# This is the step  261
# This is the step  262
# This is the step  263
# This is the step  264
# This is the step  265
# This is the step  266
# This is the step  267
# This is the step  268
# This is the step  269
# This is the step  270
# This is the step  271
# This is the step  272
# This is the step  273
# This is the step  274
# This is the step  275
# This is the step  276
# This is the step  277
# This is the step  278
# This is the step  279
# This is the step  280
# This is the step  281
# This is the step  282
# This is the step  283
# This is the step  284
# This is the step  285
# This is the step  286
# This is the step  287
# This is the step  288
# This is the step  289
# This is the step  290
# This is the step  291
# This is the step  292
# This is the step  293
# This is the step  294
# This is the step  295
# This is the step  296
# This is the step  297
# This is the step  298
# This is the step  299
# This is the step  300
# This is the step  301
# This is the step  302
# This is the step  303
# This is the step  304
# This is the step  305
# This is the step  306
# This is the step  307
# This is the step  308
# This is the step  309
# This is the step  310
# This is the step  311
# This is the step  312
# This is the step  313
# This is the step  314
# This is the step  315
# This is the step  316
# This is the step  317
# This is the step  318
# This is the step  319
# This is the step  320
# This is the step  321
# This is the step  322
# This is the step  323
# This is the step  324
# This is the step  325
# This is the step  326
# This is the step  327
# This is the step  328
# This is the step  329
# This is the step  330
# This is the step  331
# This is the step  332
# This is the step  333
# This is the step  334
# This is the step  335
# This is the step  336
# This is the step  337
# This is the step  338
# This is the step  339
# This is the step  340
# This is the step  341
# This is the step  342
# This is the step  343
# This is the step  344
# This is the step  345
# This is the step  346
# This is the step  347
# This is the step  348
# This is the step  349
# This is the step  350
# This is the step  351
# This is the step  352
# This is the step  353
# This is the step  354
# This is the step  355
# This is the step  356
# This is the step  357
# This is the step  358
# This is the step  359
# This is the step  360
# This is the step  361
# This is the step  362
# This is the step  363
# This is the step  364
# This is the step  365
# This is the step  366
# This is the step  367
# This is the step  368
# This is the step  369
# This is the step  370
# This is the step  371
# This is the step  372
# This is the step  373
# This is the step  374
# This is the step  375
# This is the step  376
# This is the step  377
# This is the step  378
# This is the step  379
# This is the step  380
# This is the step  381
# This is the step  382
# This is the step  383
# This is the step  384
# This is the step  385
# This is the step  386
# This is the step  387
# This is the step  388
# This is the step  389
# This is the step  390
# This is the step  391
# This is the step  392
# This is the step  393
# This is the step  394
# This is the step  395
# This is the step  396
# This is the step  397
# This is the step  398
# This is the step  399
# This is the step  400
# This is the step  401
# This is the step  402
# This is the step  403
# This is the step  404
# This is the step  405
# This is the step  406
# This is the step  407
# This is the step  408
# This is the step  409
# This is the step  410
# This is the step  411
# This is the step  412
# This is the step  413
# This is the step  414
# This is the step  415
# This is the step  416
# This is the step  417
# This is the step  418
# This is the step  419
# This is the step  420
# This is the step  421
# This is the step  422
# This is the step  423
# This is the step  424
# This is the step  425
# This is the step  426
# This is the step  427
# This is the step  428
# This is the step  429
# This is the step  430
# This is the step  431
# This is the step  432
# This is the step  433
# This is the step  434
# This is the step  435
# This is the step  436
# This is the step  437
# This is the step  438
# This is the step  439
# This is the step  440
# This is the step  441
# This is the step  442
# This is the step  443
# This is the step  444
# This is the step  445
# This is the step  446
# This is the step  447
# This is the step  448
# This is the step  449
# This is the step  450
# This is the step  451
# This is the step  452
# This is the step  453
# This is the step  454
# This is the step  455
# This is the step  456
# This is the step  457
# This is the step  458
# This is the step  459
# This is the step  460
# This is the step  461
# This is the step  462
# This is the step  463
# This is the step  464
# This is the step  465
# This is the step  466
# This is the step  467
# This is the step  468
# This is the step  469
# This is the step  470
# This is the step  471
# This is the step  472
# This is the step  473
# This is the step  474
# This is the step  475
# This is the step  476
# This is the step  477
# This is the step  478
# This is the step  479
# This is the step  480
# This is the step  481
# This is the step  482
# This is the step  483
# This is the step  484
# This is the step  485
# This is the step  486
# This is the step  487
# This is the step  488
# This is the step  489
# This is the step  490
# This is the step  491
# This is the step  492
# This is the step  493
# This is the step  494
# This is the step  495
# This is the step  496
# This is the step  497
# This is the step  498
# This is the step  499
# This is the step  500
# This is the step  501
# This is the step  502
# This is the step  503
# This is the step  504
# This is the step  505
# This is the step  506
# This is the step  507
# This is the step  508
# This is the step  509
# This is the step  510
# This is the step  511
# This is the step  512
# This is the step  513
# This is the step  514
# This is the step  515
# This is the step  516
# This is the step  517
# This is the step  518
# This is the step  519
# This is the step  520
# This is the step  521
# This is the step  522
# This is the step  523
# This is the step  524
# This is the step  525
# This is the step  526
# This is the step  527
# This is the step  528
# This is the step  529
# This is the step  530
# This is the step  531
# This is the step  532
# This is the step  533
# This is the step  534
# This is the step  535
# This is the step  536
# This is the step  537
# This is the step  538
# This is the step  539
# This is the step  540
# This is the step  541
# This is the step  542
# This is the step  543
# This is the step  544
# This is the step  545
# This is the step  546
# This is the step  547
# This is the step  548
# This is the step  549
# This is the step  550
# This is the step  551
# This is the step  552
# This is the step  553
# This is the step  554
# This is the step  555
# This is the step  556
# This is the step  557
# This is the step  558
# This is the step  559
# This is the step  560
# This is the step  561
# This is the step  562
# This is the step  563
# This is the step  564
# This is the step  565
# This is the step  566
# This is the step  567
# This is the step  568
# This is the step  569
# This is the step  570
# This is the step  571
# This is the step  572
# This is the step  573
# This is the step  574
# This is the step  575
# This is the step  576
# This is the step  577
# This is the step  578
# This is the step  579
# This is the step  580
# This is the step  581
# This is the step  582
# This is the step  583
# This is the step  584
# This is the step  585
# This is the step  586
# This is the step  587
# This is the step  588
# This is the step  589
# This is the step  590
# This is the step  591
# This is the step  592
# This is the step  593
# This is the step  594
# This is the step  595
# This is the step  596
# This is the step  597
# This is the step  598
# This is the step  599
# This is the step  600
# This is the step  601
# This is the step  602
# This is the step  603
# This is the step  604
# This is the step  605
# This is the step  606
# This is the step  607
# This is the step  608
# This is the step  609
# This is the step  610
# This is the step  611
# This is the step  612
# This is the step  613
# This is the step  614
# This is the step  615
# This is the step  616
# This is the step  617
# This is the step  618
# This is the step  619
# This is the step  620
# This is the step  621
# This is the step  622
# This is the step  623
# This is the step  624
# This is the step  625
# This is the step  626
# This is the step  627
# This is the step  628
# This is the step  629
# This is the step  630
# This is the step  631
# This is the step  632
# This is the step  633
# This is the step  634
# This is the step  635
# This is the step  636
# This is the step  637
# This is the step  638
# This is the step  639
# This is the step  640
# This is the step  641
# This is the step  642
# This is the step  643
# This is the step  644
# This is the step  645
# This is the step  646
# This is the step  647
# This is the step  648
# This is the step  649
# This is the step  650
# This is the step  651
# This is the step  652
# This is the step  653
# This is the step  654
# This is the step  655
# This is the step  656
# This is the step  657
# This is the step  658
# This is the step  659
# This is the step  660
# This is the step  661
# This is the step  662
# This is the step  663
# This is the step  664
# This is the step  665
# This is the step  666
# This is the step  667
# This is the step  668
# This is the step  669
# This is the step  670
# This is the step  671
# This is the step  672
# This is the step  673
# This is the step  674
# This is the step  675
# This is the step  676
# This is the step  677
# This is the step  678
# This is the step  679
# This is the step  680
# This is the step  681
# This is the step  682
# This is the step  683
# This is the step  684
# This is the step  685
# This is the step  686
# This is the step  687
# This is the step  688
# This is the step  689
# This is the step  690
# This is the step  691
# This is the step  692
# This is the step  693
# This is the step  694
# This is the step  695
# This is the step  696
# This is the step  697
# This is the step  698
# This is the step  699
# This is the step  700
# This is the step  701
# This is the step  702
# This is the step  703
# This is the step  704
# This is the step  705
# This is the step  706
# This is the step  707
# This is the step  708
# This is the step  709
# This is the step  710
# This is the step  711
# This is the step  712
# This is the step  713
# This is the step  714
# This is the step  715
# This is the step  716
# This is the step  717
# This is the step  718
# This is the step  719
# This is the step  720
# This is the step  721
# This is the step  722
# This is the step  723
# This is the step  724
# This is the step  725
# This is the step  726
# This is the step  727
# This is the step  728
# This is the step  729
# This is the step  730
# This is the step  731
# This is the step  732
# This is the step  733
# This is the step  734
# This is the step  735
# This is the step  736
# This is the step  737
# This is the step  738
# This is the step  739
# This is the step  740
# This is the step  741
# This is the step  742
# This is the step  743
# This is the step  744
# This is the step  745
# This is the step  746
# This is the step  747
# This is the step  748
# This is the step  749
# This is the step  750
# This is the step  751
# This is the step  752
# This is the step  753
# This is the step  754
# This is the step  755
# This is the step  756
# This is the step  757
# This is the step  758
# This is the step  759
# This is the step  760
# This is the step  761
# This is the step  762
# This is the step  763
# This is the step  764
# This is the step  765
# This is the step  766
# This is the step  767
# This is the step  768
# This is the step  769
# This is the step  770
# This is the step  771
# This is the step  772
# This is the step  773
# This is the step  774
# This is the step  775
# This is the step  776
# This is the step  777
# This is the step  778
# This is the step  779
# This is the step  780
# This is the step  781
# This is the step  782
# This is the step  783
# This is the step  784
# This is the step  785
# This is the step  786
# This is the step  787
# This is the step  788
# This is the step  789
# This is the step  790
# This is the step  791
# This is the step  792
# This is the step  793
# This is the step  794
# This is the step  795
# This is the step  796
# This is the step  797
# This is the step  798
# This is the step  799
# This is the step  800
# This is the step  801
# This is the step  802
# This is the step  803
# This is the step  804
# This is the step  805
# This is the step  806
# This is the step  807
# This is the step  808
# This is the step  809
# This is the step  810
# This is the step  811
# This is the step  812
# This is the step  813
# This is the step  814
# This is the step  815
# This is the step  816
# This is the step  817
# This is the step  818
# This is the step  819
# This is the step  820
# This is the step  821
# This is the step  822
# This is the step  823
# This is the step  824
# This is the step  825
# This is the step  826
# This is the step  827
# This is the step  828
# This is the step  829
# This is the step  830
# This is the step  831
# This is the step  832
# This is the step  833
# This is the step  834
# This is the step  835
# This is the step  836
# This is the step  837
# This is the step  838
# This is the step  839
# This is the step  840
# This is the step  841
# This is the step  842
# This is the step  843
# This is the step  844
# This is the step  845
# This is the step  846
# This is the step  847
# This is the step  848
# This is the step  849
# This is the step  850
# This is the step  851
# This is the step  852
# This is the step  853
# This is the step  854
# This is the step  855
# This is the step  856
# This is the step  857
# This is the step  858
# This is the step  859
# This is the step  860
# This is the step  861
# This is the step  862
# This is the step  863
# This is the step  864
# This is the step  865
# This is the step  866
# This is the step  867
# This is the step  868
# This is the step  869
# This is the step  870
# This is the step  871
# This is the step  872
# This is the step  873
# This is the step  874
# This is the step  875
# This is the step  876
# This is the step  877
# This is the step  878
# This is the step  879
# This is the step  880
# This is the step  881
# This is the step  882
# This is the step  883
# This is the step  884
# This is the step  885
# This is the step  886
# This is the step  887
# This is the step  888
# This is the step  889
# This is the step  890
# This is the step  891
# This is the step  892
# This is the step  893
# This is the step  894
# This is the step  895
# This is the step  896
# This is the step  897
# This is the step  898
# This is the step  899
# This is the step  900
# This is the step  901
# This is the step  902
# This is the step  903
# This is the step  904
# This is the step  905
# This is the step  906
# This is the step  907
# This is the step  908
# This is the step  909
# This is the step  910
# This is the step  911
# This is the step  912
# This is the step  913
# This is the step  914
# This is the step  915
# This is the step  916
# This is the step  917
# This is the step  918
# This is the step  919
# This is the step  920
# This is the step  921
# This is the step  922
# This is the step  923
# This is the step  924
# This is the step  925
# This is the step  926
# This is the step  927
# This is the step  928
# This is the step  929
# This is the step  930
# This is the step  931
# This is the step  932
# This is the step  933
# This is the step  934
# This is the step  935
# This is the step  936
# This is the step  937
# This is the step  938
# This is the step  939
# This is the step  940
# This is the step  941
# This is the step  942
# This is the step  943
# This is the step  944
# This is the step  945
# This is the step  946
# This is the step  947
# This is the step  948
# This is the step  949
# This is the step  950
# This is the step  951
# This is the step  952
# This is the step  953
# This is the step  954
# This is the step  955
# This is the step  956
# This is the step  957
# This is the step  958
# This is the step  959
# This is the step  960
# This is the step  961
# This is the step  962
# This is the step  963
# This is the step  964
# This is the step  965
# This is the step  966
# This is the step  967
# This is the step  968
# This is the step  969
# This is the step  970
# This is the step  971
# This is the step  972
# This is the step  973
# This is the step  974
# This is the step  975
# This is the step  976
# This is the step  977
# This is the step  978
# This is the step  979
# This is the step  980
# This is the step  981
# This is the step  982
# This is the step  983
# This is the step  984
# This is the step  985
# This is the step  986
# This is the step  987
# This is the step  988
# This is the step  989
# This is the step  990
# This is the step  991
# This is the step  992
# This is the step  993
# This is the step  994
# This is the step  995
# This is the step  996
# This is the step  997
# This is the step  998
# This is the step  999
# True
